# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabrualvarez/Minox/blob/main/IA_BUENO%20con%20google.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📦 Instala librerías necesarias
# !pip install pandas openpyxl

# %%
# 📚 1. Importaciones necesarias
import pandas as pd

# %%
# Podemos utilizar el método read_excel para leer datos de un fichero Excel
df = pd.read_excel('/content/Proyecto_IA.xlsx')

# Veamos las 5 primeras filas de nuestro fichero Excel para comprobar que todo esta correctamente
df.head()
# Out:
#             Serie        Modelo Aumento             Control por app Abertura  \
# 0  Cámara trampeo      DTC 1200     NaN  Si (gratis, Android e iOS)      NaN
# 1  Cámara trampeo  DTC 550 WiFi     NaN  Si (gratis, Android e iOS)      NaN
# 2  Cámara trampeo       DTC 550     NaN                          No      NaN
# 3  Cámara trampeo       DTC 460     NaN                          No      NaN
# 4  Cámara trampeo       DTC 395     NaN                          No      NaN
#
#    Recorrido de ajuste (MOA)  Diámetro de lente (mm) Localización GPS  \
# 0                        NaN                     NaN               Si
# 1                        NaN                     NaN               No
# 2                        NaN                     NaN               No
# 3                        NaN                     NaN               No
# 4                        NaN                     NaN               No
#
#    Ajuste por clic (MOA)  Tamaño del punto rojo (MOA)  ... Rosca trípode  \
# ...

# %%
# Convertir columnas a minúsculas para evitar errores
df.columns = [col.strip().lower() for col in df.columns]

# %%
# Buscar modelos por serie y mostrar tabla con serie + modelo
def buscar_modelos_por_serie(serie):
    serie = serie.strip().lower()

    # Filtrar registros que contengan el nombre parcial de la serie
    resultados = df[df['serie'].str.lower().str.contains(serie, na=False)]

    if resultados.empty:
        return f"No se encontraron modelos que pertenezcan a una serie que contenga: '{serie}'."

    # Seleccionar solo columnas deseadas y eliminar duplicados
    tabla = resultados[['serie', 'modelo']].drop_duplicates()

    # Devolver el DataFrame directamente para que Colab lo muestre en formato tabla
    return tabla.reset_index(drop=True)

# %%
buscar_modelos_por_serie("RS-4")
# Out:
#   serie         modelo
# 0  RS-4     1-6x24 (S)
# 1  RS-4  1.6-10x42 (S)
# 2  RS-4  2.2-14x50 (S)
# 3  RS-4    3-18x56 (S)
# 4  RS-4         1-4x24
# 5  RS-4      2.5-10x50
# 6  RS-4      2.5-10x42
# 7  RS-4        3-12x56

# %%
# Buscar modelos por serie y mostrar tabla con serie + modelo
def buscar_numero_material(modelo):
    modelo = modelo.strip().lower()

    # Filtrar registros que contengan el nombre parcial de la serie
    resultados = df[df['modelo'].str.lower().str.contains(modelo, na=False)]

    if resultados.empty:
        return f"No se encontraron numeros de materiales que pertenezcan al modelo: '{modelo}'."

    # Seleccionar todas las columnas deseadas en una sola tabla
    columnas = ['modelo', 'serie', 'numero material']
    columnas_existentes = [col for col in columnas if col in df.columns]

    # Un solo DataFrame
    return resultados[columnas_existentes].drop_duplicates().reset_index(drop=True)

# %%
buscar_numero_material("dtc")
# Out:
#                                                modelo           serie  \
# 0                                            DTC 1200  Cámara trampeo
# 1                                        DTC 550 WiFi  Cámara trampeo
# 2                                             DTC 550  Cámara trampeo
# 3                                             DTC 460  Cámara trampeo
# 4                                             DTC 395  Cámara trampeo
# 5          Cubrecámara para DTC 460 Versión 1 (Roble)      Accesorios
# 6         Cubrecámara para DTC 460 Versión 2 (Abedul)      Accesorios
# 7           Cubrecámara para DTC 460 Versión 3 (Haya)      Accesorios
# 8        Caja para baterías para DTC 460 (Dos piezas)      Accesorios
# 9                   Kit de seguridad para cámaras DTC      Accesorios
# 10  Cargador para baterías Basic 4 / Para pilas re...      Accesorios
# 11          Caja de protección antirrobo para DTC 550      Accesorios
#
#     numero material
# 0          80406283
# ...

# %%
# Características de uno o varios modelos con formato de moneda en el precio
def caracteristicas_modelo(nombre_modelo):
    nombre_modelo = nombre_modelo.strip().lower()

    # Filtrar modelos que contengan ese texto
    coincidencias = df[df['modelo'].str.lower().str.contains(nombre_modelo, na=False)]

    if coincidencias.empty:
        return f"No se encontraron modelos que contengan '{nombre_modelo}'."

    columnas_deseadas = ['modelo', 'serie', 'aumento', 'dimensiones', 'peso (g)', 'nº material', 'precio']
    columnas_existentes = [col for col in columnas_deseadas if col in df.columns]
    tabla = coincidencias[columnas_existentes].copy()

    # 👉 Formatear la columna "precio" si existe
    if 'precio' in tabla.columns:
        tabla['precio'] = tabla['precio'].apply(lambda x: f"{x} €" if pd.notnull(x) else x)

    return tabla.reset_index(drop=True)

# %%
caracteristicas_modelo("DTC 550 WiFi")
# Out:
#          modelo           serie aumento dimensiones  peso (g) precio
# 0  DTC 550 WiFi  Cámara trampeo     NaN  138x200x45       290  188 €

# %%
import re

def precio_de_modelo(filtro):
    filtro = filtro.strip().lower()

    # Si se solicita ver todos los productos
    if filtro == "" or filtro == "todos":
        resultados = df[['modelo', 'precio']].dropna().copy()

    # Si es un rango tipo "entre 100 y 200"
    elif ("entre" in filtro and "y" in filtro) or ("entre" in filtro and "-" in filtro):
        numeros = re.findall(r"\d+(?:[.,]\d+)?", filtro)
        if len(numeros) == 2:
            min_val = float(numeros[0].replace(",", "."))
            max_val = float(numeros[1].replace(",", "."))
            resultados = df[(df['precio'] >= min_val) & (df['precio'] <= max_val)][['modelo', 'precio']].copy()
        else:
            return "No entendí bien el rango. Usa por ejemplo: 'entre 100 y 300'"

    # Si es tipo "mayor de 300"
    elif "mayor de" in filtro:
        numero = re.search(r"\d+(?:[.,]\d+)?", filtro)
        if numero:
            val = float(numero.group().replace(",", "."))
            resultados = df[df['precio'] > val][['modelo', 'precio']].copy()
        else:
            return "Indica un número válido después de 'mayor de'."

    # Si es tipo "menor de 300"
    elif "menor de" in filtro:
        numero = re.search(r"\d+(?:[.,]\d+)?", filtro)
        if numero:
            val = float(numero.group().replace(",", "."))
            resultados = df[df['precio'] < val][['modelo', 'precio']].copy()
        else:
            return "Indica un número válido después de 'menor de'."

    # Si es búsqueda por nombre parcial del modelo
    else:
        resultados = df[df['modelo'].str.lower().str.contains(filtro, na=False)][['modelo', 'precio']].copy()

    # Si no se encuentra nada
    if resultados.empty:
        print ("Prueba con:")
        print("- entre 100 y 200")
        print("- mayor de 300")
        print("- menor de 250")
        print("- DTC")
        print("- Todos")

    # Ordenar y dar formato
    resultados = resultados.drop_duplicates().sort_values(by='precio')
    resultados['precio'] = resultados['precio'].apply(lambda x: f"{x:,.2f} €" if pd.notnull(x) else x)

    return resultados.reset_index(drop=True)

# %%
precio_de_modelo("dtc")
# Out:
#                                                modelo    precio
# 0   Cargador para baterías Basic 4 / Para pilas re...   18.00 €
# 1        Caja para baterías para DTC 460 (Dos piezas)   20.00 €
# 2                   Kit de seguridad para cámaras DTC   21.00 €
# 3         Cubrecámara para DTC 460 Versión 2 (Abedul)   26.00 €
# 4          Cubrecámara para DTC 460 Versión 1 (Roble)   26.00 €
# 5           Cubrecámara para DTC 460 Versión 3 (Haya)   26.00 €
# 6           Caja de protección antirrobo para DTC 550   33.00 €
# 7                                             DTC 395  135.00 €
# 8                                            DTC 1200  150.00 €
# 9                                             DTC 460  159.00 €
# 10                                       DTC 550 WiFi  188.00 €
# 11                                            DTC 550  200.00 €

# %%
# Buscar modelos por serie y mostrar tabla con serie + modelo
def dimensiones_de_modelo(nombre_modelo):
    nombre_modelo = nombre_modelo.strip().lower()

    # Filtrar registros que contengan el nombre parcial de la serie
    resultados = df[df['modelo'].str.lower().str.contains(nombre_modelo, na=False)]

    if resultados.empty:
        return f"No se encontraron modelos que pertenezcan a una serie que contenga: '{nombre_modelo}'."

    # Seleccionar solo columnas deseadas y eliminar duplicados
    tabla = resultados[['dimensiones', 'modelo', 'serie']].drop_duplicates()

    # Devolver el DataFrame directamente para que Colab lo muestre en formato tabla
    return tabla.reset_index(drop=True)

# %%
dimensiones_de_modelo("rv")
# Out:
#   dimensiones modelo            serie
# 0    64x43x37     RV  Punto rojo RV 1

# %%
def responder_peso(pregunta):
    pregunta = pregunta.strip().lower()

    if 'modelo' not in df.columns or 'peso (g)' not in df.columns:
        return "Las columnas necesarias no están disponibles en el DataFrame."

    # Caso: entre X y Y
    if "entre" in pregunta and "y" in pregunta:
        numeros = re.findall(r"\d+(?:[.,]\d+)?", pregunta)
        if len(numeros) == 2:
            min_val = float(numeros[0].replace(",", "."))
            max_val = float(numeros[1].replace(",", "."))
            resultados = df[(df['peso (g)'] >= min_val) & (df['peso (g)'] <= max_val)][['modelo', 'peso (g)']].copy()
        else:
            return "No se entendió bien el rango. Usa por ejemplo: 'entre 300 y 600'"

    # Caso: mayor de X
    elif "mayor de" in pregunta:
        num = re.search(r"\d+(?:[.,]\d+)?", pregunta)
        if num:
            val = float(num.group().replace(",", "."))
            resultados = df[df['peso (g)'] > val][['modelo', 'peso (g)']].copy()
        else:
            return "Indica un número válido después de 'mayor de'."

    # Caso: menor de X
    elif "menor de" in pregunta:
        num = re.search(r"\d+(?:[.,]\d+)?", pregunta)
        if num:
            val = float(num.group().replace(",", "."))
            resultados = df[df['peso (g)'] < val][['modelo', 'peso (g)']].copy()
        else:
            return "Indica un número válido después de 'menor de'."

    # Caso general: modelo por texto parcial
    else:
        resultados = df[df['modelo'].str.lower().str.contains(pregunta, na=False)][['modelo', 'peso (g)']].copy()

    if resultados.empty:
        return f"No se encontraron modelos relacionados con '{pregunta}'."

    # Formatear peso con "g"
    resultados['peso (g)'] = resultados['peso (g)'].apply(lambda x: f"{x} g" if pd.notnull(x) else x)
    resultados = resultados.drop_duplicates().sort_values(by='peso (g)')

    return resultados.reset_index(drop=True)

# %%
responder_peso("mayor de 500 g")
# Out:
#                modelo peso (g)
# 0                8x56   1250 g
# 1                8x56   1280 g
# 2            MD 60 ZR   1620 g
# 3            MD 80 ZR   2190 g
# 4                8×34    505 g
# 5   Trípode universal    550 g
# 6          1-6x24 (S)    560 g
# 7                8x33    570 g
# 8               10x33    570 g
# 9               10x42    590 g
# 10               8x42    610 g
# 11          2.5-10x42    635 g
# 12      1.6-10x42 (S)    635 g
# 13              2-10x    650 g
# 14              10×42    650 g
# 15          2.5-10x50    660 g
# 16               8×42    685 g
# 17            MD 50 W    690 g
# 18              10×42    705 g
# 19               8x44    720 g
# 20              10x44    720 g
# 21               8×42    725 g
# 22      2.2-14x50 (S)    725 g
# 23            3-12x56    745 g
# 24              3-15x    760 g
# 25             7.5x44    780 g
# 26        3-18x56 (S)    800 g
# 27    Set de limpieza    896 g
# 28        ZP5 3-15x50    920 g
# ...

# %%
def buscar_pesos(modelo):
    modelo = modelo.strip().lower()

    # Verificar que las columnas existen
    if 'serie' not in df.columns or 'modelo' not in df.columns or 'peso (g)' not in df.columns:
        return "Las columnas necesarias no están disponibles en el DataFrame."

    # Filtrar por coincidencia parcial del modelo
    resultados = df[df['modelo'].str.lower().str.contains(modelo, na=False)]

    if resultados.empty:
        return f"No se encontraron modelos que contengan '{modelo}'."

    # Seleccionar y formatear columnas
    tabla = resultados[['serie', 'modelo', 'peso (g)']].dropna().drop_duplicates()
    tabla['peso (g)'] = tabla['peso (g)'].apply(lambda x: f"{x} g" if pd.notnull(x) else x)

    return tabla.reset_index(drop=True)

# %%
buscar_pesos("dtc")
# Out:
#              serie                                             modelo peso (g)
# 0   Cámara trampeo                                           DTC 1200    460 g
# 1   Cámara trampeo                                       DTC 550 WiFi    290 g
# 2   Cámara trampeo                                            DTC 550    290 g
# 3   Cámara trampeo                                            DTC 460    415 g
# 4   Cámara trampeo                                            DTC 395    280 g
# 5       Accesorios         Cubrecámara para DTC 460 Versión 1 (Roble)    258 g
# 6       Accesorios        Cubrecámara para DTC 460 Versión 2 (Abedul)    284 g
# 7       Accesorios          Cubrecámara para DTC 460 Versión 3 (Haya)     84 g
# 8       Accesorios       Caja para baterías para DTC 460 (Dos piezas)    100 g
# 9       Accesorios                  Kit de seguridad para cámaras DTC     63 g
# 10      Accesorios  Cargador para baterías Basic 4 / Para pilas re...     78 g
# ...

# %%
# Introducimos el chatbot y toda la información que queremos que nos muestre cuando se ejecute esta función
def chatbot():
    print("🤖 ¡Hola! Soy tu asistente de Minox.")
    print("Puedes preguntarme cosas como:")
    print("- Modelo de la serie (ej:'modelo de la serie RS-4')")
    print("- Caracteristicas del modelo (ej: 'Modelo DTC 1200')")
    print("- Precio de los productos (ej: 'Precio de DTC 1200')")
    print("- Dimensiones de los produstos (ej: 'Dimensiones de DTC 1200)")
    print("- Peso de los productos (ej: 'Peso de DTC 1200)")
    print("- Número de material de los productos (ej: 'Número de material de DTC 1200)")
    print("Escribe 'salir' para terminar.\n")

# %%
# Función principal para iniciar el chatbot
def iniciar_chatbot():
    # Llama a la función chatbot()
    chatbot()

    # Bucle infinito para mantener la conversación hasta que el usuario escriba "salir"
    while True:
        try:
            # Solicita al usuario una pregunta, la convierte a minúsculas para facilitar la comparación
            pregunta = input("Tú: ").lower()

            # Si el usuario quiere salir, se rompe el bucle
            if pregunta == "salir":
                print("👋 ¡Hasta luego!")
                break

            # Si la pregunta contiene palabras clave relacionadas con los modelos de una serie
            elif any(p in pregunta for p in ["modelo de la serie", "modelos de la serie", "modelos", "modelo"]):
                serie = input("🔹 ¿Nombre de la serie?: ")
                from IPython.display import display  # Importación local para mostrar resultados en notebooks
                display(buscar_modelos_por_serie(serie))  # Muestra los modelos de la serie especificada

            # Si la pregunta es sobre precios
            elif any(p in pregunta for p in ["precio", "cuánto", "vale", "coste", "costaría"]):
                nombre = input("🔹 ¿Nombre del modelo?: ")
                from IPython.display import display
                display(precio_de_modelo(nombre))  # Muestra el precio del modelo

            # Si la pregunta es sobre dimensiones
            elif any(p in pregunta for p in ["dimensiones", "dimensiones de", "medidas", "medida", "dimensión"]):
                modelo = input("🔹 ¿Nombre del modelo?: ")
                from IPython.display import display
                display(dimensiones_de_modelo(modelo))  # Muestra las dimensiones del modelo

            # Si la pregunta es sobre características generales o materiales
            elif any(p in pregunta for p in ["caracteristicas", "materiales", "informacion", "caracteristica"]):
                modelo = input("🔹 ¿Nombre del modelo?: ")
                from IPython.display import display
                display(caracteristicas_modelo(modelo))  # Muestra información del modelo

            # Si la pregunta es sobre el número de material (código SAP)
            elif any(p in pregunta for p in ["numero material", "número de material", "sap", "números materiales"]):
                modelo = input("🔹 ¿Nombre del modelo?: ")
                from IPython.display import display
                display(buscar_numero_material(modelo))  # Muestra el número de material

            # Si la pregunta es sobre el peso
            elif any(p in pregunta for p in ["peso material", "peso", "pesos", "peso modelos"]):
                modelo = input("🔹 ¿Nombre del modelo?: ")
                from IPython.display import display
                display(responder_peso(modelo))  # Muestra el peso del modelo

            # Si no se reconoce la intención de la pregunta
            else:
                print("Lo siento, no entendí tu pregunta. Intenta reformularla.")

        # Captura cualquier error durante la ejecución para evitar que se interrumpa el bucle
        except Exception as e:
            print(f"⚠️ Se produjo un error: {e}")
            continue

# %%
# Ejecutamo el chatbot y le hacemos las preguntas
iniciar_chatbot()
# Out:
# 🤖 ¡Hola! Soy tu asistente de Minox.
# Puedes preguntarme cosas como:
# - Modelo de la serie (ej:'modelo de la serie RS-4')
# - Caracteristicas del modelo (ej: 'Modelo DTC 1200')
# - Precio de los productos (ej: 'Precio de DTC 1200')
# - Dimensiones de los produstos (ej: 'Dimensiones de DTC 1200)
# - Peso de los productos (ej: 'Peso de DTC 1200)
# - Número de material de los productos (ej: 'Número de material de DTC 1200)
# Escribe 'salir' para terminar.
#
# Tú: precios minox
# 🔹 ¿Nombre del modelo?: MD 80 ZR
#      modelo      precio
# 0  MD 80 ZR  1,851.00 €
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-140-2735411084.py in <cell line: 0>()
#       1 # Ejecutamo el chatbot y le hacemos las preguntas
# ----> 2 iniciar_chatbot()
#
# /tmp/ipython-input-137-3128599772.py in iniciar_chatbot()
#       8         try:
# ...

# %%
#Introducimos gemini al código

# %%
# !pip install -q -U google-generativeai

# %%
# Importamos el paquete recien instalado
import google.generativeai as genai

# Esto es para usar secrets, la nueva opción de Google Colab, para almacenar la API key
from google.colab import userdata

# %%
import textwrap
from IPython.display import display
from IPython.display import Markdown

# Esta función se usa para dejar el formato Markdown que devuelve Gemini en formato compatible con Colab
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Configuramos nuestra instancia del modelo con nuestra API key
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

genai.configure(api_key = GOOGLE_API_KEY)

# %%
# Define una variable model, usando gemini-pro

model = genai.GenerativeModel("gemini-1.5-flash")

# %%
response = model.generate_content("¿Qué es la marca de prismáticos minox?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-147-1952148184.py in <cell line: 0>()
# ----> 1 response = model.generate_content("¿Qué es la marca de prismáticos minox?")
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
# ...

# %%
# %%time
response = model.generate_content("¿Qué es la marca de prismáticos minox?")
# Out:
# CPU times: user 134 ms, sys: 17.9 ms, total: 152 ms
# Wall time: 17.7 s

# %%
print(response.text)
# Out:
# Minox es una marca de renombre mundial conocida por fabricar **óptica de alta calidad**, incluyendo prismáticos, pero también cámaras, visores nocturnos y otros equipos ópticos.  Se caracterizan por su:
#
# * **Diseño compacto y ligero:** A menudo se les elogia por su portabilidad sin sacrificar significativamente el rendimiento.
# * **Buena calidad de imagen:**  Aunque no son los prismáticos más económicos del mercado, ofrecen una imagen nítida y clara, con una buena transmisión de luz.
# * **Durabilidad:**  Se construyen con materiales resistentes y están diseñados para soportar condiciones adversas.
# * **Precio medio-alto:**  Se posicionan en un rango de precios superior al de las marcas de entrada, reflejando la calidad de sus componentes y su fabricación.
#
# ...

# %%
to_markdown(response.text)
# Out:
# > Minox es una marca de renombre mundial conocida por fabricar **óptica de alta calidad**, incluyendo prismáticos, pero también cámaras, visores nocturnos y otros equipos ópticos.  Se caracterizan por su:
# >
# > * **Diseño compacto y ligero:** A menudo se les elogia por su portabilidad sin sacrificar significativamente el rendimiento.
# > * **Buena calidad de imagen:**  Aunque no son los prismáticos más económicos del mercado, ofrecen una imagen nítida y clara, con una buena transmisión de luz.
# > * **Durabilidad:**  Se construyen con materiales resistentes y están diseñados para soportar condiciones adversas.
# > * **Precio medio-alto:**  Se posicionan en un rango de precios superior al de las marcas de entrada, reflejando la calidad de sus componentes y su fabricación.
# >
# ...

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
response.prompt_feedback

# %%
# Cambiamos a Gemini Pro
model = genai.GenerativeModel('gemini-1.5-flash')

# Iniciamos el chat sin ninguna historia previa
chat = model.start_chat(history=[])

# %%
response = chat.send_message("trabajo en la empresa de prismaticos minox y me gustaría saber más información sobre ella")
to_markdown(response.text)
# Out:
# > MINOX es una empresa con una larga y rica historia en la fabricación de ópticas de alta calidad.  Para darte información precisa sobre la empresa desde la perspectiva de un empleado, necesito saber en qué área trabajas dentro de MINOX.  Tu rol afectará la información que te sea relevante.
# >
# > Sin embargo, puedo ofrecerte información general que te puede ser útil independientemente de tu puesto:
# >
# > **Historia y Tradición:** MINOX es conocida por su larga historia en la fabricación de productos ópticos, incluyendo cámaras miniatura, prismáticos, telescopios y miras telescópicas. Su reputación se basa en la calidad, precisión y durabilidad de sus productos.  Investigar la historia de la empresa te dará una perspectiva sobre sus valores y evolución.
# >
# > **Productos y Mercados:**  MINOX se centra en productos de alta gama para diversos mercados, incluyendo:
# >
# ...

# %%
response = chat.send_message("vivo en madrid y trabajo en Blaser, empresa que distribuye la marca de prismaticos minox y me gustaría saber más información sobre ella")
to_markdown(response.text)
# Out:
# > Trabajas en Blaser en Madrid, que distribuye la marca Minox.  Eso aclara mucho las cosas.  Para obtener información sobre Minox, te recomiendo que consultes estos recursos *internos* primero, ya que tendrás acceso a información privilegiada:
# >
# > * **Tu intranet corporativa:**  Blaser probablemente tenga una intranet con información detallada sobre sus proveedores, incluyendo Minox.  Busca información sobre sus productos, historia, y datos de contacto.
# > * **Tus colegas:**  Habla con tus compañeros de trabajo en el departamento de compras, marketing o ventas.  Ellos seguramente tendrán mucha información sobre Minox.
# > * **Material de marketing interno:**  Blaser seguramente tiene presentaciones, catálogos o documentos internos sobre Minox que te puedan proporcionar información detallada.
# ...

# %%
response = chat.send_message("Serías capaz de responder preguntas sobre visores y prismaticos minox con el documento excel que hay subido en la plataforma de google collab?")
to_markdown(response.text)
# Out:
# > No puedo acceder a archivos locales ni a internet, incluyendo Google Colab.  No tengo la capacidad de ver o procesar el contenido de ningún documento, incluyendo hojas de cálculo de Excel, que no esté directamente incluido en mi prompt.  Para obtener respuestas a tus preguntas sobre los visores y prismáticos Minox, deberás proporcionar la información relevante del documento Excel aquí mismo.  Puedo ayudarte a analizar esa información una vez que la tengas disponible en nuestro diálogo.

# %%
response = chat.send_message("como puedo crear esos pronts para que puedas responderme todos los datos tecnicos del excel?")
to_markdown(response.text)
# Out:
# > No puedo acceder directamente a archivos externos como un archivo Excel en Google Colab.  Para que pueda responder a tus preguntas sobre los datos técnicos, necesitas copiar y pegar la información relevante del Excel aquí.  No necesitas copiar la hoja completa, sólo las columnas y filas con los datos técnicos que te interesan.
# >
# >
# > Para facilitarme la tarea y obtener respuestas precisas, te recomiendo lo siguiente al copiar y pegar los datos:
# >
# > * **Formato tabular:** Usa un formato de tabla, con columnas y filas claramente definidas.  Puedes usar "|" para separar las columnas y usar una nueva línea para separar las filas.  Por ejemplo:
# >
# > ```
# > Modelo|Aumento|Diámetro objetivo|Campo de visión|Peso
# > -------|-------|-------|-------|-------
# > MD 8x25|8x|25mm|7.5°|290g
# > BL 10x42|10x|42mm|6.5°|750g
# > ... etc
# > ```
# >
# ...

# %%
response = chat.send_message("Como puedo copiar datos de excel aqui para que lo puedas leer?")
to_markdown(response.text)
# Out:
# > La mejor manera de copiar datos de Excel para que yo pueda leerlos es usando un formato de texto plano,  como se explicó antes.  No puedo interpretar imágenes ni archivos adjuntos.
# >
# > Aquí hay dos métodos:
# >
# > **Método 1: Copiar y pegar como texto plano:**
# >
# > 1. **Selecciona los datos en Excel:** Resalta las celdas que contienen la información técnica que te interesa.
# > 2. **Copiar:** Usa el atajo de teclado Ctrl+C (o Cmd+C en Mac).
# > 3. **Pegar como texto plano:**  En nuestro chat,  haz clic derecho y selecciona "Pegar como texto plano" o una opción similar (puede variar dependiendo de tu navegador).  Esto evitará que se peguen formatos de Excel que yo no puedo interpretar.  Algunos navegadores te permiten pegar directamente con Ctrl+Shift+V, que suele ser la opción "Pegar como texto sin formato".
# ...

# %%
response = chat.send_message("""Serie     Modelo  Aumento Dimensiones     Peso (g)        Numero material Precio
Cámara trampeo  DTC 1200                154x130x45      460     80406283        150,00 €
Cámara trampeo  DTC 550 WiFi            138x200x45      290     80407270        188,00 €
Cámara trampeo  DTC 550         40x43x38        290     80405434        200,00 €
Cámara trampeo  DTC 460         280 x 77 x 310 mm       415     80406281        159,00 €
Cámara trampeo  DTC 395         250 x 87 x 210 mm       280     80405444        135,00 €
RS-4    1-6x24 (S)      1 - 6.  240 x 78 x 310 mm       560     80118303        1.437,00 €
RS-4    1.6-10x42 (S)   1.6 - 10        64x47x33        635     80118305        1.437,00 €
RS-4    2.2-14x50 (S)   2.2 - 14        102 x 78 x 310 mm       725     80118747        1.657,00 €
RS-4    3-18x56 (S)     3 - 18. 180 x 78 x 311 mm       800     80118749        1.714,00 €
RS-4    1-4x24  1 - 4.  250 x 77 x 310 mm       470     80413876        721,00 €
RS-4    2.5-10x50       2.5 - 10        64x41x37        660     80413878        917,00 €
RS-4    2.5-10x42       2.5 - 10        138 x 94 x 345 mm       635     80413879        890,00 €
RS-4    3-12x56 3 - 12. 134 x 94 x 345 mm       745     80413880        917,00 €
Long-range      5-25x56 LR      5-25.   64x43x39        940     80413882        1.946,00 €
Allrounder 1-5x24       1-5x    1-5.    177 x 78 x 310 mm       480     80413884        1.155,00 €
Allrounder 2-10x50      2-10x   2-10.   130×115×43      650     80413885        1.365,00 €
Allrounder 3-15x56      3-15x   3-15.   138 x 79x 310 mm        760     80413886        1.470,00 €
Pro ZP5 ZP5 3-15x50     3-15.   137 x 78 x 320 mm       920     80413887        2.899,00 €
Pro ZP5 ZP5 5-25x56     5-25.   138 x 94 x 345 mm       970     80413881        3.223,00 €
Punto rojo RV 1 RV      1       64x43x37        96      80224005        307,00 €
MD 60 ZR        MD 60 ZR        12- 40. 138 x 78 x 310 mm       1620    80405436        1.350,00 €
MD 80 ZR        MD 80 ZR        20- 60. 138 x 94 x 385 mm       2190    80405437        1.851,00 €
MD 50 W MD 50 W 16- 30. 245 x 63 x 135 mm       690     80405421        255,00 €
X-universal     8×42    8       235 x 61 x 135 mm       725     80405422        450,00 €
X-universal     10×42   10      275 x 63 x 135 mm       705     80405423        470,00 €
X-universal     10×50   10      235 x 63 x 135 mm       925     80405424        510,00 €
X-tour  8×26    8       117×110×38      325     80416200        186,00 €
X-tour  10×26   10      114×110×38      310     80416201        198,00 €
X-tour  8×34    8       122×115×43      505     80416202        224,00 €
X-tour  10×34   10      112×115×43      500     80416203        236,00 €
X-tour  8×42    8       146×115×50      685     80416204        266,00 €
X-tour  10×42   10      141×115×50      650     80416206        284,00 €
X-range 10x42   10      152x132x52      990     80408390        1.140,00 €
X-range 8x42    8       152x132x52      990     80408390        1.140,00 €
X-HD    8x44    8       150x130x53      720     80107486        805,00 €
X-HD    10x44   10      150x130x53      720     80107487        835,00 €
X-HD    8x56    8       195x160x70      1250    80107488        1.006,00 €
X-active        8x25    8       113x114x35      325     80407330        206,00 €
X-active        10x25   10      113x114x35      325     80407331        255,00 €
""")
to_markdown(response.text)
# Out:
# > Esta tabla proporciona una excelente visión general de los precios de varios productos MINOX, incluyendo cámaras trampa y prismáticos.  Los precios están en Euros (€) y, como se mencionó anteriormente, pueden variar según el distribuidor y las ofertas especiales.  Es importante tener en cuenta que esta es una instantánea en el tiempo y los precios pueden cambiar.
# >
# > La tabla es muy útil para comparar precios entre diferentes modelos dentro de la misma línea de producto (por ejemplo, las diferentes cámaras trampa DTC o los prismáticos de la serie RS-4).  También muestra la considerable diferencia de precio entre las líneas de productos, desde las cámaras trampa más económicas hasta los prismáticos de gama alta como la serie Pro ZP5.

# %%
response = chat.send_message("Cuales son los precios de los DTC?")
to_markdown(response.text)
# Out:
# > Según la tabla de precios que proporcionaste anteriormente, los precios de las cámaras trampa MINOX DTC son los siguientes:
# >
# > * **DTC 1200:** 150,00 €
# > * **DTC 550 WiFi:** 188,00 €
# > * **DTC 550:** 200,00 €
# > * **DTC 460:** 159,00 €
# > * **DTC 395:** 135,00 €
# >
# > Recuerda que estos precios son los que aparecen en la tabla y pueden no reflejar los precios actuales en todos los distribuidores.  Es siempre recomendable verificar con un distribuidor autorizado o en la página web oficial de MINOX para obtener los precios más actualizados.

# %%
response = chat.send_message("""Serie     Modelo  Aumento Dimensiones     Peso (g)        Numero material Precio
X-active        8x33    8       138x130x45      570     80407333        287,00 €
X-active        10x33   10      138x130x45      570     80407334        465,00 €
X-lite  8x44    8       150x133x53      720     80407335        308,00 €
X-lite  10x44   10      150x133x53      720     80407336        304,00 €
X-lite  8x56    8       195x160x70      1280    80407337        105,00 €
X-lite  8x26    8       117x113x35      290     80407325        133,00 €
X-lite  10x26   10      117x113x35      290     80407326        143,00 €
X-lite  8x34    8       133x124x43      450     80408167        173,00 €
X-lite  10x34   10      133x124x43      450     80408168        184,00 €
X-lite  8x42    8       145x121x52      610     80407327        206,00 €
X-lite  10x42   10      145x121x52      590     80407328        224,00 €
X-lite  8x56    8       166x147x66      970     80407329        349,00 €
RAPID   7.5x44  7,5     150x131x53      780     80405445        504,00 €
Accesorios      Trípode universal               150x130x53      550     80405832        64,00 €
Accesorios      Set de limpieza         150x130x53      896     80405463        42,00 €
Accesorios      Correa Professional para prismáticos            150x130x53      52      80405790        73,00 €
Accesorios      Cubrecámara para DTC 460 Versión 1 (Roble)              160x130x53      258     80408100        26,00 €
Accesorios      Cubrecámara para DTC 460 Versión 2 (Abedul)             198x140x53      284     80408099        26,00 €
Accesorios      Cubrecámara para DTC 460 Versión 3 (Haya)               150x120x53      84      80408098        26,00 €
Accesorios      Caja para baterías para DTC 460 (Dos piezas)            174x135x53      100     80408097        20,00 €
Accesorios      Kit de seguridad para cámaras DTC               150x130x53      63      80106554        21,00 €
Accesorios      Cargador para baterías Basic 4 / Para pilas recargables AA para cámaras DTC             155x130x53      78      80226267        18,00 €
Accesorios      Set de 4 pilas recargables AA / 2.500 mAh Ni MH         150x130x53      25      80226268        23,00 €
Accesorios      Set de 2 pilas recargables AA / 2.500 mAh Ni MH         174x130x52      41      80226269        12,00 €
Accesorios      Caja de protección antirrobo para DTC 550               150x140x53      74      80226270        33,00 €
""")
to_markdown(response.text)
# Out:
# > Esta tabla muestra los precios de los prismáticos MINOX de las series X-active, X-lite y RAPID, así como una variedad de accesorios.  Aquí están los precios de los prismáticos, desglosados por serie y modelo:
# >
# > **Serie X-active:**
# >
# > * **8x33:** 287,00 €
# > * **10x33:** 465,00 €
# >
# > **Serie X-lite:**
# >
# > * **8x44:** 308,00 €
# > * **10x44:** 304,00 €
# > * **8x56:** 105,00 €
# > * **8x26:** 133,00 €
# > * **10x26:** 143,00 €
# > * **8x34:** 173,00 €
# > * **10x34:** 184,00 €
# > * **8x42:** 206,00 €
# > * **10x42:** 224,00 €
# > * **8x56:** 349,00 €
# >
# > **Serie RAPID:**
# >
# > * **7.5x44:** 504,00 €
# >
# > **Importante:** Recuerda que estos precios son los que aparecen en la tabla que me has proporcionado y pueden no reflejar los precios actuales en todos los distribuidores.  Siempre es recomendable verificar los precios con un distribuidor autorizado o en la página web oficial de MINOX para obtener la información más actualizada.

# %%
response = chat.send_message("Cuáles son las medidas de las cámara trampeo?")
to_markdown(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-113-816984742.py in <cell line: 0>()
# ----> 1 response = chat.send_message("Cuáles son las medidas de las cámara trampeo?")
#       2 to_markdown(response.text)
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     576             )
#     577
# --> 578         response = self.model.generate_content(
#     579             contents=history,
#     580             generation_config=generation_config,
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
# ...

# %%
response = chat.send_message("Cuales son los precios de los DTC?")
to_markdown(response.text)
# Out:
# > No puedo darte los precios exactos de los prismáticos MINOX DTC.  Los precios de los productos MINOX, al igual que los de cualquier otra marca, varían según:
# >
# > * **Modelo específico:**  La línea DTC probablemente tiene diferentes modelos con diferentes características y, por lo tanto, diferentes precios.  Un DTC 8x42 será diferente en precio a un DTC 10x42, por ejemplo.
# > * **Distribuidor:**  Los precios pueden variar entre diferentes tiendas y distribuidores autorizados.
# > * **Ofertas y promociones:**  Las tiendas a menudo tienen ofertas especiales, descuentos o promociones que afectan el precio final.
# > * **Ubicación geográfica:** Los precios pueden variar según el país o región debido a factores como impuestos, aranceles y costos de envío.
# >
# >
# > Para obtener información precisa sobre los precios de los prismáticos MINOX DTC, te recomiendo:
# >
# ...

# %%
response = chat.send_message("Como podria hacer un chatbot interactivo con el cliente con la informacion de los minox?")
to_markdown(response.text)
# Out:
# > Crear un chatbot interactivo para clientes con información de MINOX requiere una combinación de diseño de conversación, una plataforma de chatbot y una base de datos de productos. Aquí te detallo los pasos y consideraciones:
# >
# > **1. Diseño de la Conversación (Flujo de Usuario):**
# >
# > * **Define el propósito:** ¿Qué quieren lograr los clientes al interactuar con el chatbot?  Ejemplos: encontrar un producto específico, comparar modelos, conocer precios, encontrar un distribuidor cercano, resolver problemas técnicos, etc.
# > * **Crea un mapa de flujo de conversación:**  Este mapa visualiza las posibles rutas que puede tomar la conversación, desde la bienvenida inicial hasta la resolución del problema del cliente.  Incluye frases clave y posibles respuestas del usuario.  Considera diferentes escenarios y caminos.
# ...

# %%
# Introducimos el chatbot de gradio

# %%
# !pip install gradio

# %%
# !pip install -q --upgrade google-generativeai python-dotenv gradio pandas openpyxl

# %%
import google.generativeai as genai
import pandas as pd
import gradio as gr
import os
from dotenv import load_dotenv

# %%
import pydub
import moviepy
print(gr.__version__) ## 3.34.0
# Out:
# 5.38.0

# %%
def greet(name):
    return "Hello, " + name + "!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text", allow_flagging="never")
demo.launch(share=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/interface.py:425: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b81e04f39489d5b2af.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b81e04f39489d5b2af.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=GEMINI_API_KEY)

# Paso 4: Cargar el Excel con productos Minox
df = pd.read_excel("/content/Proyecto_IA.xlsx")  # asegúrate que el archivo esté en la misma carpeta

# Paso 5: Preparar el modelo de Gemini
model = genai.GenerativeModel("gemini-pro")

# %%
from getpass import getpass
import os

api_key = getpass("Introduce tu API Key de Gemini: ")
os.environ["GEMINI_API_KEY"] = api_key
# Out:
# Introduce tu API Key de Gemini: ··········

# %%
import requests

response = requests.post(
    "https://api.tuapi.com/endpoint",
    headers={"Authorization": "Bearer TU_API_KEY"},
    timeout=10  # segundos
)

# %%
def tu_funcion_respuesta(mensaje):
    try:
        # Limitamos el contexto para evitar sobrecargar a Gemini
        contexto = df.head(10).to_dict(orient="records")  # o selecciona las filas relevantes si prefieres

        prompt = f"""
        Eres un experto en productos ópticos de la marca Minox. Responde a la siguiente pregunta
        usando SOLO esta información extraída del catálogo en Excel:\n
        {contexto}
        \nPregunta: {mensaje}
        """

        respuesta = model.generate_content(prompt)
        return respuesta.text.strip()

    except Exception as e:
        return f"Ha ocurrido un error: {str(e)}"

# Paso 7: Crear interfaz visual con Gradio
def responder_usuario(mensaje):
    return tu_funcion_respuesta(mensaje)

interfaz = gr.Interface(
    fn=responder_usuario,
    inputs="text",
    outputs="text",
    title="Chatbot Minox IA",
    description="Haz preguntas sobre visores, prismáticos y otros productos Minox."
)

interfaz.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c9d235a06dacd4ddfa.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c9d235a06dacd4ddfa.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
